# %%
# Libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
from io import StringIO
from datetime import datetime

# %%
# Show columns and rows in terminal
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
# Função para buscar os dataframes por título
def obter_dataframes_por_titulos(url, titulos_desejados):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    tabelas = soup.find_all('table', {'class': 'wikitable'})

    dataframes_encontrados = [
        (tabela.find_previous(['h2', 'h3']).text.strip().replace('[editar]', '').strip(), pd.read_html(StringIO(str(tabela)), flavor='bs4')[0])
        for tabela in tabelas
        for titulo_desejado in titulos_desejados
        if titulo_desejado.lower() in tabela.find_previous(['h2', 'h3']).text.lower()
    ]

    return dataframes_encontrados

# Função para criar o nome do arquivo com a data atual
def gerar_nome_arquivo():
    data_hoje = datetime.today().strftime('%Y-%m-%d')
    return f"tabelas_brasileirao2025_{data_hoje}.xlsx"

# Função para pegar os títulos
def obter_titulos_desejados():
    return [titulo.strip() for titulo in input("Digite os títulos que deseja buscar (separados por vírgula): ").split(',')]

# Função para salvar os dataframes no arquivo Excel
def salvar_tabelas_excel(dataframes, nome_arquivo):
    with pd.ExcelWriter(nome_arquivo) as writer:
        for i, (titulo, df) in enumerate(dataframes):
            print(f"\nTítulo: {titulo}\n{df.to_string(index=False)}")
            
            # Cria nome de aba válido
            aba = titulo[:31].replace('/', '-').replace('\\', '-')
            df.to_excel(writer, sheet_name=f"Aba {i + 1} - {aba}", index=False)
    
    print(f"\n Tabelas salvas com sucesso em '{nome_arquivo}'")

def main():
    titulos_desejados = obter_titulos_desejados()
    url = "https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol_de_2025_-_S%C3%A9rie_A"

    dataframes = obter_dataframes_por_titulos(url, titulos_desejados)

    if dataframes:
        nome_arquivo = gerar_nome_arquivo()
        salvar_tabelas_excel(dataframes, nome_arquivo)
    else:
        print(f"Nenhum dataframe encontrado para os títulos: {', '.join(titulos_desejados)}.")

if __name__ == "__main__":
    main()
# Out:
# Título: Classificação
#  Pos           Equipevde   Pts  J  V  E  D  GP  GC SG                    Classificação ou descenso
#    1           Palmeiras    13  5  4  1  0   7   2 +5  Fase de grupos da Copa Libertadores de 2026
#    2            Flamengo    11  5  3  2  0  11   2 +9  Fase de grupos da Copa Libertadores de 2026
#    3          Fluminense 10[a]  5  3  1  1   6   4 +2  Fase de grupos da Copa Libertadores de 2026
#    4 Red Bull Bragantino 10[a]  5  3  1  1   6   4 +2  Fase de grupos da Copa Libertadores de 2026
#    5               Ceará     7  5  2  1  2   7   6 +1    Segunda fase da Copa Libertadores de 2026
#    6         Corinthians  7[b]  5  2  1  2   6   6  0    Segunda fase da Copa Libertadores de 2026
#    7            Cruzeiro  7[b]  5  2  1  2   6   6  0 Fase de grupos da Copa Sul-Americana de 2026
#    8       Vasco da Gama     7  5  2  1  2   6   7 −1 Fase de grupos da Copa Sul-Americana de 2026
#    9           Juventude     7  5  2  1  2   6  11 −5 Fase de grupos da Copa Sul-Americana de 2026
#   10           São Paulo     7  5  1  4  0   5   4 +1 Fase de grupos da Copa Sul-Americana de 2026
#   11            Mirassol     6  5  1  3  1   9   7 +2 Fase de grupos da Copa Sul-Americana de 2026
#   12       Internacional     6  5  1  3  1   5   3 +2 Fase de grupos da Copa Sul-Americana de 2026
#   13               Bahia     6  5  1  3  1   5   7 −2                                          NaN
#   14           Fortaleza     5  5  1  2  2   5   5  0                                          NaN
#   15            Botafogo     5  5  1  2  2   4   4  0                                          NaN
#   16             Vitória     5  5  1  2  2   6   8 −2                                          NaN
#   17    Atlético Mineiro     5  5  1  2  2   4   6 −2                 Rebaixados à Série B de 2026
#   18              Santos     4  5  1  1  3   6   7 −1                 Rebaixados à Série B de 2026
#   19              Grêmio     4  5  1  1  3   4  10 −6                 Rebaixados à Série B de 2026
#   20               Sport     1  5  0  1  4   3   8 −5                 Rebaixados à Série B de 2026
#
# Título: Confrontos
# Mandante \ Visitante ATM BAH BOT CEA COR CRU FLA FLU FOR GRE INT JUV MIR PAL RBB SAN SPA SPT VAS VIT
#     Atlético Mineiro   — NaN 1–0 NaN   a   a   a   a NaN NaN NaN NaN NaN NaN NaN NaN 0–0 NaN   a 2–2
#                Bahia NaN   —   a 1–0 1–1 NaN NaN   a NaN NaN NaN NaN 1–1 NaN NaN NaN NaN   a   a   a
#             Botafogo   a   a   — NaN   a NaN   a   a NaN   a NaN 2–0 NaN   a NaN   a 2–2 NaN   a NaN
#                Ceará NaN NaN NaN   — NaN NaN NaN NaN   a 2–0 NaN NaN NaN NaN NaN NaN NaN NaN 2–1 NaN
#          Corinthians   a   a   a NaN   —   a   a 0–2 NaN   a   a NaN NaN   a NaN   a   a 2–1 3–0 NaN
#             Cruzeiro   a 3–0 NaN NaN   a   — NaN   a NaN NaN NaN NaN 2–1   a NaN NaN   a NaN   a NaN
#             Flamengo   a NaN   a NaN   a NaN   —   a NaN   a 1–1 6–0 NaN   a NaN   a   a NaN   a NaN
#           Fluminense   a   a   a NaN   a   a   a   — NaN   a   a NaN NaN   a 2–1 1–0   a NaN   a 1–1
#            Fortaleza NaN NaN NaN   a NaN NaN NaN 2–0   — NaN 0–0 NaN NaN 1–2 NaN NaN NaN NaN NaN NaN
#               Grêmio 2–1 NaN   a NaN   a NaN 0–2   a NaN   — 1–1   a NaN   a NaN   a   a NaN NaN NaN
#        Internacional NaN NaN NaN NaN   a 3–0   a   a NaN   a   —   a NaN 0–1 NaN NaN NaN NaN   a NaN
#            Juventude NaN NaN NaN 2–1 NaN NaN NaN NaN NaN   a   a   — 2–2 NaN NaN NaN NaN NaN NaN 2–0
#             Mirassol NaN NaN NaN NaN NaN NaN NaN NaN 1–1 4–1 NaN NaN   — NaN NaN NaN NaN NaN NaN NaN
#            Palmeiras NaN NaN 0–0 NaN 2–0   a   a   a NaN   a NaN NaN NaN   — NaN   a   a NaN   a NaN
#  Red Bull Bragantino NaN NaN 1–0 2–2 NaN 1–0 NaN NaN NaN NaN NaN NaN NaN NaN   — NaN NaN NaN NaN NaN
#               Santos 2–0 2–2   a NaN   a NaN   a   a NaN   a NaN NaN NaN   a NaN   —   a NaN   a NaN
#            São Paulo NaN NaN   a NaN   a 1–1   a   a NaN   a NaN NaN NaN   a NaN 2–1   — 0–0   a NaN
#                Sport NaN   a NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN 1–2 0–1 NaN NaN   — NaN NaN
#        Vasco da Gama   a   a   a NaN   a   a 0–0   a NaN   a   a NaN NaN   a NaN 2–1   a 3–1   — NaN
#              Vitória NaN   a NaN NaN NaN NaN 1–2 NaN 2–1 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN   —
#
# Título: Desempenho por rodada
# Rodada ↓ ATM BAH BOT CEA COR CRU FLA FLU FOR GRE INT JUV MIR PAL RBB SAN SPA SPT VAS VIT
#      1.ª  16  11  14   7   8   4   8  19   1   4  10   2  18  14   6  17  12  13   3  20
#      2.ª  19  13   5   3   2  12   6   9   4  10   1   8  17   7  15  16  14  18  11  20
#      3.ª  16  14  10   8   9  12   1   5   7  13   6   3  17   2  11  18  15  20   4  19
#      4.ª  19  18  11   4  14   5   1   3  12  17  10   8   9   2   6  13  16  20   7  15
#      5.ª  17  13  15   5   6   7   2   3  14  19  12   9  11   1   4  18  10  20   8  16
#      6.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#      7.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#      8.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#      9.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     10.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     11.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     12.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     13.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     14.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     15.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     16.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     17.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     18.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     19.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     20.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     21.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     22.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     23.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     24.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     25.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     26.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     27.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     28.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     29.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     30.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     31.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     32.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     33.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     34.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     35.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     36.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     37.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#     38.ª NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# Rodada ↑ ATM BAH BOT CEA COR CRU FLA FLU FOR GRE INT JUV MIR PAL RBB SAN SPA SPT VAS VIT
#
#  Tabelas salvas com sucesso em 'tabelas_brasileirao2025_2025-04-23.xlsx'
